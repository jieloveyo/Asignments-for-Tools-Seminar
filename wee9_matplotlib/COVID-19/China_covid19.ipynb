# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Confirmed = pd.read_csv("csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv")
Death = pd.read_csv("csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv")
Recovered = pd.read_csv("csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv")

# %%
Confirmed.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/8/20  4/9/20  4/10/20  4/11/20  4/12/20  \
# 0        0        0        0  ...     444     484      521      555      607
# 1        0        0        0  ...     400     409      416      433      446
# 2        0        0        0  ...    1572    1666     1761     1825     1914
# 3        0        0        0  ...     564     583      601      601      638
# 4        0        0        0  ...      19      19       19       19       19
#
# ...

# %%
drop_attr = ['Lat','Long']
Confirmed.drop(drop_attr,axis=1,inplace=True)
Death.drop(drop_attr,axis=1,inplace=True)
Recovered.drop(drop_attr,axis=1,inplace=True)

# %%
China_confirmed = Confirmed[Confirmed["Country/Region"] == 'China']
China_death = Death[Death["Country/Region"] == 'China']
China_recovered = Recovered[Recovered["Country/Region"] == 'China']

# %%
China_confirmed.head()
# Out:
#    Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 49          Anhui          China        1        9       15       39       60
# 50        Beijing          China       14       22       36       41       68
# 51      Chongqing          China        6        9       27       57       75
# 52         Fujian          China        1        5       10       18       35
# 53          Gansu          China        0        2        2        4        7
#
#     1/27/20  1/28/20  1/29/20  ...  4/8/20  4/9/20  4/10/20  4/11/20  4/12/20  \
# 49       70      106      152  ...     990     991      991      991      991
# 50       80       91      111  ...     588     588      588      589      589
# 51      110      132      147  ...     579     579      579      579      579
# 52       59       80       84  ...     351     351      351      351      352
# 53       14       19       24  ...     139     139      139      139      139
#
# ...

# %%
drop_attr = ['Province/State','Country/Region']
China_confirmed.drop(drop_attr,axis=1,inplace=True)
China_recovered.drop(drop_attr,axis=1,inplace=True)
China_death.drop(drop_attr,axis=1,inplace=True)
# Out:
# C:\Users\jlovey\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
China_confirmed.head()
# Out:
#     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  \
# 49        1        9       15       39       60       70      106      152
# 50       14       22       36       41       68       80       91      111
# 51        6        9       27       57       75      110      132      147
# 52        1        5       10       18       35       59       80       84
# 53        0        2        2        4        7       14       19       24
#
#     1/30/20  1/31/20  ...  4/8/20  4/9/20  4/10/20  4/11/20  4/12/20  4/13/20  \
# 49      200      237  ...     990     991      991      991      991      991
# 50      114      139  ...     588     588      588      589      589      589
# 51      182      211  ...     579     579      579      579      579      579
# 52      101      120  ...     351     351      351      351      352      352
# 53       26       29  ...     139     139      139      139      139      139
#
#     4/14/20  4/15/20  4/16/20  4/17/20
# ...

# %%
y_confirmed = China_confirmed.sum(axis=0)
y_recovered = China_recovered.sum(axis=0)
y_death = China_death.sum(axis=0)

# %%
y_death
# Out:
# 1/22/20      17
# 1/23/20      18
# 1/24/20      26
# 1/25/20      42
# 1/26/20      56
#            ...
# 4/13/20    3345
# 4/14/20    3345
# 4/15/20    3346
# 4/16/20    3346
# 4/17/20    4636
# Length: 87, dtype: int64

# %%
type(y_death)
# Out:
# pandas.core.series.Series

# %%
y_confirmed.plot(label='y_confirmed',linewidth=2,c='r')
y_recovered.plot(label='y_recovered',linewidth=2,c='g')
y_death.plot(label='y_death',linewidth=2)
plt.legend()
plt.savefig('China_line.pdf')

# %%
plt.title
# Out:
# <function matplotlib.pyplot.title(label, fontdict=None, loc=None, pad=None, **kwargs)>
